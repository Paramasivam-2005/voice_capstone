# %%
from openai import OpenAI
from IPython.display import Audio, display,Javascript
from scipy.io.wavfile import write,read
from base64 import b64decode
import sounddevice as sd
import time
import json
import re

# %%
client = OpenAI(
    api_key = "sk-YMU3vf-ofzirb1BnrBqyig", # Changed nexus_api_key to api_key
    base_url="https://apidev.navigatelabsai.com/" # Changed base to base_url and added comma
)
